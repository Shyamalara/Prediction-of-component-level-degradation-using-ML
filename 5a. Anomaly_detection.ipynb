# %% [markdown]
# ### Importing the data

# %%
import numpy as np 
import pandas as pd

# %%
## importing the data
## pressure sensors are imported as PS. There are around 6 pressure sensors. They are named as ps1, ps2, ps3, ps4, ps5, ps6. 

df_ps1 = pd.read_csv('PS1.txt', delimiter = '\t', header = None)
df_ps2 = pd.read_csv('PS2.txt', delimiter = '\t', header = None)
df_ps3 = pd.read_csv('PS3.txt', delimiter = '\t', header = None)
df_ps4 = pd.read_csv('PS4.txt', delimiter = '\t', header = None)
df_ps5 = pd.read_csv('PS5.txt', delimiter = '\t', header = None)
df_ps6 = pd.read_csv('PS6.txt', delimiter = '\t', header = None)

# %%
## cooling efficiency and cooling power are imported as ce and cp respectively. 

df_ce = pd.read_csv('CE.txt',delimiter = '\t', header = None)
df_cp = pd.read_csv('CP.txt', delimiter = '\t', header = None)

# %%
# temperature sensors are imported as ts. There are around 4 pressure sensors. They are named as ts1, ts2, ts3, ts4.

df_ts1 = pd.read_csv('TS1.txt', delimiter = '\t', header = None)
df_ts2 = pd.read_csv('TS2.txt', delimiter = '\t', header = None)
df_ts3 = pd.read_csv('TS3.txt', delimiter = '\t', header = None)
df_ts4 = pd.read_csv('TS4.txt', delimiter = '\t', header = None)

# %%
# flow sensors are imported as fs. There are around 2 pressure sensors. They are named as fs1, fs2.

df_fs1 = pd.read_csv('FS1.txt', delimiter = '\t', header = None)
df_fs2 = pd.read_csv('FS2.txt', delimiter = '\t', header = None)

# %%
# motor power sensors is imported as eps. 
# vibration sensors is imported as vs
# efficiency power is imported as se

df_eps1 = pd.read_csv('EPS1.txt', delimiter = '\t', header = None)
df_se = pd.read_csv('SE.txt', delimiter = '\t', header = None)
df_vs1 = pd.read_csv('VS1.txt', delimiter = '\t', header = None)

# %%
## function for defining variables like ps1_1, ps1_2 for 17 sensors with different sampling rates

def col(n, var):
    l = []
    for i in range(1,n):
        temp = str(var) + '_' + '%d' %i
        l.append(temp)
    return l

# %%
# 
df_ps1.columns = col(6001,'ps1')
df_ps2.columns = col(6001,'ps2')
df_ps3.columns = col(6001,'ps3')
df_ps4.columns = col(6001,'ps4')
df_ps5.columns = col(6001,'ps5')
df_ps6.columns = col(6001,'ps6')

# %%
df_ts1.columns = col(61,'ts1')
df_ts2.columns = col(61,'ts2')
df_ts3.columns = col(61,'ts3')
df_ts4.columns = col(61,'ts4')

# %%
df_eps1.columns = col(6001,'eps1')

# %%
df_fs1.columns = col(601,'fs1')
df_fs2.columns = col(601,'fs2')

# %%
df_vs1.columns = col(61,'vs1')

# %%
df_ce.columns = col(61,'ce')

# %%
df_cp.columns = col(61,'cp')

# %%
df_se.columns = col(61,'se')

# %%
df_ps = pd.concat([df_ps1, df_ps2, df_ps3, df_ps4, df_ps5, df_ps6], axis = 1)
df_ts = pd.concat([df_ts1, df_ts2, df_ts3, df_ts4], axis = 1)
df_fs = pd.concat([df_fs1, df_fs2], axis = 1)
df_vir = pd.concat([df_cp, df_ce, df_eps1, df_se, df_vs1], axis = 1)
df_ts.head()
# Out:
#     ts1_1   ts1_2   ts1_3   ts1_4   ts1_5   ts1_6   ts1_7   ts1_8   ts1_9  \
# 0  35.570  35.492  35.469  35.422  35.414  35.320  35.227  35.242  35.160
# 1  36.156  36.094  35.992  36.008  35.992  35.902  35.824  35.820  35.727
# 2  37.488  37.391  37.340  37.312  37.223  37.145  37.059  36.973  36.898
# 3  38.633  38.535  38.469  38.379  38.297  38.223  38.125  38.062  37.977
# 4  39.461  39.461  39.375  39.281  39.203  39.113  39.043  38.969  38.875
#
#    ts1_10  ...  ts4_51  ts4_52  ts4_53  ts4_54  ts4_55  ts4_56  ts4_57  \
# 0  35.176  ...  33.180  33.172  33.363  33.340  33.324  33.410  33.504
# 1  35.727  ...  34.980  34.980  34.977  34.977  35.062  35.047  35.129
# 2  36.879  ...  35.980  36.039  36.051  36.062  36.039  36.047  36.066
# 3  37.969  ...  36.875  36.867  36.941  36.941  36.937  36.934  36.941
# 4  38.883  ...  37.687  37.695  37.770  37.758  37.766  37.766  37.773
#
#    ts4_58  ts4_59  ts4_60
# 0  33.582  33.594  33.555
# 1  35.148  35.141  35.121
# ...

# %%
df = pd.concat([df_ps, df_ts, df_fs, df_vir], axis = 1)
df.head()
# Out:
#     ps1_1   ps1_2   ps1_3   ps1_4   ps1_5   ps1_6   ps1_7   ps1_8   ps1_9  \
# 0  151.47  151.45  151.52  151.27  150.80  150.69  153.89  154.67  152.88
# 1  151.11  151.12  151.16  150.92  150.70  150.62  152.40  153.21  152.81
# 2  150.81  150.79  150.84  150.65  150.35  150.23  152.03  152.81  152.44
# 3  150.48  150.47  150.52  150.31  150.04  149.98  151.63  152.48  152.24
# 4  150.41  150.35  150.24  150.12  149.87  149.71  151.64  152.37  151.78
#
#    ps1_10  ...  vs1_51  vs1_52  vs1_53  vs1_54  vs1_55  vs1_56  vs1_57  \
# 0  153.82  ...   0.554   0.552   0.545   0.553   0.553   0.539   0.544
# 1  153.53  ...   0.555   0.547   0.548   0.544   0.536   0.542   0.540
# 2  153.27  ...   0.543   0.544   0.543   0.554   0.544   0.544   0.545
# 3  152.94  ...   0.549   0.538   0.553   0.543   0.553   0.555   0.544
# 4  152.68  ...   0.546   0.546   0.544   0.552   0.539   0.540   0.549
#
#    vs1_58  vs1_59  vs1_60
# 0   0.545   0.535   0.543
# 1   0.533   0.531   0.534
# ...

# %%
def conversion(df):
    df1 = pd.DataFrame()
    df1 = df.median(axis=1) ## AVERAGE ALONG THE ROW
    return df1

# %%
PS1 = pd.DataFrame(conversion(df_ps1))
PS1.columns = ['PS1']

PS2 = pd.DataFrame(conversion(df_ps2))
PS2.columns = ['PS2']

PS3 = pd.DataFrame(conversion(df_ps3))
PS3.columns = ['PS3']

PS4 = pd.DataFrame(conversion(df_ps4))
PS4.columns = ['PS4']

PS5 = pd.DataFrame(conversion(df_ps5))
PS5.columns = ['PS5']

PS6 = pd.DataFrame(conversion(df_ps6))
PS6.columns = ['PS6']

# %%
TS1 = pd.DataFrame(conversion(df_ts1))
TS1.columns = ['TS1']

TS2 = pd.DataFrame(conversion(df_ts2))
TS2.columns = ['TS2']

TS3 = pd.DataFrame(conversion(df_ts3))
TS3.columns = ['TS3']

TS4 = pd.DataFrame(conversion(df_ts4))
TS4.columns = ['TS4']

# %%
FS1 = pd.DataFrame(conversion(df_fs1))
FS1.columns = ['FS1']

FS2 = pd.DataFrame(conversion(df_fs2))
FS2.columns = ['FS2']

# %%
P1 = pd.DataFrame(conversion(df_eps1))
P1.columns = ['P1']

VS1 = pd.DataFrame(conversion(df_vs1))
VS1.columns = ['VS1']

CE1 = pd.DataFrame(conversion(df_ce))
CE1.columns = ['CE1']

CP1 = pd.DataFrame(conversion(df_cp))
CP1.columns = ['CP1']


SE1 = pd.DataFrame(conversion(df_se))
SE1.columns = ['SE1']

# %%
X = pd.concat([PS1, PS2, PS3, PS4, PS5, PS6, FS1, FS2, TS1, TS2, TS3, TS4, P1, VS1, CE1, CP1, SE1], axis=1)
X.head()
# Out:
#       PS1      PS2    PS3  PS4    PS5    PS6    FS1     FS2      TS1      TS2  \
# 0  156.25  129.365  2.297  0.0  9.844  9.733  7.836  10.327  35.5720  40.9630
# 1  156.06  129.385  2.273  0.0  9.632  9.526  7.853  10.403  36.7675  41.5180
# 2  155.72  129.325  2.273  0.0  9.528  9.425  7.847  10.367  38.0235  42.4235
# 3  155.56  128.865  2.242  0.0  9.436  9.335  7.843  10.302  39.0550  43.3650
# 4  155.34  129.000  2.219  0.0  9.358  9.260  7.831  10.236  39.9670  44.3355
#
#        TS3     TS4      P1     VS1      CE1     CP1      SE1
# 0  38.4960  31.576  2479.8  0.5770  40.6755  1.9240  68.5145
# 1  38.9845  34.553  2470.0  0.5595  25.3855  1.2340  68.5360
# 2  39.6270  35.635  2457.4  0.5620  22.1040  1.1095  68.8530
# 3  40.3420  36.635  2448.0  0.5550  20.4805  1.0660  69.0060
# 4  41.3400  37.439  2440.6  0.5760  19.7985  1.0725  69.0130

# %%
X.hist(bins=50, figsize=(20, 15))

# %%
profile = pd.read_csv('profile.txt', delimiter = '\t', header = None)
profile.columns = ['cooler condition','Valve condition','Pump leakage','Hydraulic accumulator','Stable Flag']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
corr_matrix = X.corr()

#plot heat map for correlation matrix (from https://seaborn.pydata.org/examples/many_pairwise_correlations.html)

# Generate a mask for the upper triangle
mask = np.zeros_like(corr_matrix, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_matrix, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
pip install xgboost

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report, f1_score
import xgboost as xgb
import os

# %% [markdown]
# # Anomaly detection

# %%
# Extract the readings from the Not stable cycles
broken = profile[profile['Stable Flag'] == 1 ]
# Extract the names of the numerical columns
names=X.columns
# Plot time series for each sensor with BROKEN state marked with X in red color
for name in names:
    plt.figure(figsize=(18,3))
    #plt.plot(broken[name], linestyle='none', marker='X', color='red', markersize=12)
    plt.plot(X[name], color='blue')
    plt.title(name)
    plt.show()

# %%
# Extract the readings from the Stable cycles
broken = profile[profile['Stable Flag'] == 0 ]
# Extract the names of the numerical columns
names=X.columns
# Plot time series for each sensor with BROKEN state marked with X in red color
for name in names:
    plt.figure(figsize=(18,3))
    #plt.plot(broken[name], linestyle='none', marker='X', color='red', markersize=12)
    plt.plot(X[name], color='blue')
    plt.title(name)
    plt.show()

# %%
df = pd.concat([X,profile['Stable Flag']], axis = 1 )
df.head()
# Out:
#       PS1      PS2    PS3  PS4    PS5    PS6    FS1     FS2      TS1      TS2  \
# 0  156.25  129.365  2.297  0.0  9.844  9.733  7.836  10.327  35.5720  40.9630
# 1  156.06  129.385  2.273  0.0  9.632  9.526  7.853  10.403  36.7675  41.5180
# 2  155.72  129.325  2.273  0.0  9.528  9.425  7.847  10.367  38.0235  42.4235
# 3  155.56  128.865  2.242  0.0  9.436  9.335  7.843  10.302  39.0550  43.3650
# 4  155.34  129.000  2.219  0.0  9.358  9.260  7.831  10.236  39.9670  44.3355
#
#        TS3     TS4      P1     VS1      CE1     CP1      SE1  Stable Flag
# 0  38.4960  31.576  2479.8  0.5770  40.6755  1.9240  68.5145            1
# 1  38.9845  34.553  2470.0  0.5595  25.3855  1.2340  68.5360            1
# 2  39.6270  35.635  2457.4  0.5620  22.1040  1.1095  68.8530            1
# 3  40.3420  36.635  2448.0  0.5550  20.4805  1.0660  69.0060            1
# 4  41.3400  37.439  2440.6  0.5760  19.7985  1.0725  69.0130            1

# %%
# Extract the names of the numerical columns
names=X.columns
# Plot time series for each sensor with BROKEN state marked with X in red color
for name in names:
    plt.figure(figsize=(18,3))
    plt.plot(broken, linestyle='none', marker='X', color='red', markersize=5)
    plt.plot(X[name], color='blue')
    plt.title(name)
    plt.show()

# %%
# # Resample the entire dataset by daily average
# rollmean = df.resample(rule='D').mean()
# rollstd = df.resample(rule='D').std()
# # Plot time series for each sensor with its mean and standard deviation
# for name in names:
#     _ = plt.figure(figsize=(18,3))
#     _ = plt.plot(df[name], color='blue', label='Original')
#     _ = plt.plot(rollmean[name], color='red', label='Rolling Mean')
#     _ = plt.plot(rollstd[name], color='black', label='Rolling Std' )
#     _ = plt.legend(loc='best')
#     _ = plt.title(name)
#     plt.show()

# %% [markdown]
# # Preprocessing and resample

# %%
# Standardize/scale the dataset and apply PCA
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
# Extract the names of the numerical columns
df2 = df.drop(['Stable Flag'], axis=1)
names=df2.columns
x = df[names]
scaler = StandardScaler()
pca = PCA()
pipeline = make_pipeline(scaler, pca)
pipeline.fit(x)
# Plot the principal components against their inertia
features = range(pca.n_components_)
_ = plt.figure(figsize=(15, 5))
_ = plt.bar(features, pca.explained_variance_)
_ = plt.xlabel('PCA feature')
_ = plt.ylabel('Variance')
_ = plt.xticks(features)
_ = plt.title("Importance of the Principal Components based on inertia")
plt.show()

# %%
# Calculate PCA with 2 components
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents, columns = ['pc1', 'pc2'])

# %%
principalDf
# Out:
#             pc1        pc2
# 0     20.717428 -22.161528
# 1     10.954345 -11.341539
# 2     -1.587215  -7.610971
# 3    -10.928072  -4.937968
# 4    -18.261480  -2.869624
# ...         ...        ...
# 2200  22.601521 -27.738120
# 2201  22.603016 -27.752952
# 2202  21.623544 -27.686490
# 2203  22.810111 -27.666832
# 2204  24.394693 -27.830269
#
# [2205 rows x 2 columns]

# %%
from statsmodels.tsa.stattools import adfuller
# Run Augmented Dickey Fuller Test
result = adfuller(principalDf['pc1'])
# Print p-value
print(result[1])
# Out:
# 0.00018922558415120623

# %%
# # Plot ACF
# from statsmodels.graphics.tsaplots import plot_acf
# plot_acf(pca1.dropna(), lags=20, alpha=0.05)

# %%
# Calculate IQR for the 1st principal component (pc1)
q1_pc1, q3_pc1 = principalDf['pc1'].quantile([0.25, 0.75])
iqr_pc1 = q3_pc1 - q1_pc1

# %%
# Calculate upper and lower bounds for outlier for pc1
lower_pc1 = q1_pc1 - (1.5*iqr_pc1)
upper_pc1 = q3_pc1 + (1.5*iqr_pc1)

# %%
# Filter out the outliers from the pc1
principalDf['anomaly_pc1'] = ((principalDf['pc1']>upper_pc1) | (principalDf['pc1']<lower_pc1)).astype('int')
# Calculate IQR for the 2nd principal component (pc2)
q1_pc2, q3_pc2 = principalDf['pc2'].quantile([0.25, 0.75])
iqr_pc2 = q3_pc2 - q1_pc2
# Calculate upper and lower bounds for outlier for pc2
lower_pc2 = q1_pc2 - (1.5*iqr_pc2)
upper_pc2 = q3_pc2 + (1.5*iqr_pc2)

# %%
# Filter out the outliers from the pc2
principalDf['anomaly_pc2'] = ((principalDf['pc2']>upper_pc2) | (principalDf['pc2']<lower_pc2)).astype('int')
# Let's plot the outliers from pc1 on top of the sensor_11 and see where they occured in the time series
a = principalDf[principalDf['anomaly_pc1'] == 1] #anomaly
plt.figure(figsize=(18,6))
plt.plot(df['PS1'], color='blue', label='Normal')
plt.plot(df['PS1'], linestyle='none', marker='X', color='red', markersize=0.5, label='Anomaly')
plt.xlabel('Date and Time')
plt.ylabel('Sensor Reading')
plt.title('PS1 Anomalies')
plt.legend(loc='best')
plt.show();

# %%
# Let's plot the outliers from pc1 on top of the sensor_11 and see where they occured in the time series
a = principalDf[principalDf['anomaly_pc1'] == 1] #anomaly
plt.figure(figsize=(18,6))
plt.plot(df['FS1'], color='blue', label='Normal')
plt.plot(df['FS1'], linestyle='none', marker='X', color='red', markersize=1, label='Anomaly')
plt.xlabel('Date and Time')
plt.ylabel('Sensor Reading')
plt.title('FS1 Anomalies')
plt.legend(loc='best')
plt.show();

# %%
# Let's plot the outliers from pc1 on top of the sensor_11 and see where they occured in the time series
a = principalDf[principalDf['anomaly_pc1'] == 1] #anomaly
plt.figure(figsize=(18,6))
plt.plot(df['PS2'], color='blue', label='Normal')
plt.plot(df['PS2'], linestyle='none', marker='X', color='red', markersize=1, label='Anomaly')
plt.xlabel('Date and Time')
plt.ylabel('Sensor Reading')
plt.title('PS2 Anomalies')
plt.legend(loc='best')
plt.show();

# %%
# Let's plot the outliers from pc1 on top of the sensor_11 and see where they occured in the time series
a = principalDf[principalDf['anomaly_pc1'] == 1] #anomaly
plt.figure(figsize=(18,6))
plt.plot(df['PS3'], color='blue', label='Normal')
plt.plot(df['PS3'], linestyle='none', marker='X', color='red', markersize=1, label='Anomaly')
plt.xlabel('Date and Time')
plt.ylabel('Sensor Reading')
plt.title('PS3 Anomalies')
plt.legend(loc='best')
plt.show();

# %%
# Let's plot the outliers from pc1 on top of the sensor_11 and see where they occured in the time series
a = principalDf[principalDf['anomaly_pc1'] == 1] #anomaly
plt.figure(figsize=(18,6))
plt.plot(df['PS4'], color='blue', label='Normal')
plt.plot(df['PS4'], linestyle='none', marker='X', color='red', markersize=1, label='Anomaly')
plt.xlabel('Date and Time')
plt.ylabel('Sensor Reading')
plt.title('PS4 Anomalies')
plt.legend(loc='best')
plt.show();

# %%
# Let's plot the outliers from pc1 on top of the sensor_11 and see where they occured in the time series
a = principalDf[principalDf['anomaly_pc1'] == 1] #anomaly
plt.figure(figsize=(18,6))
plt.plot(df['PS5'], color='blue', label='Normal')
plt.plot(df['PS5'], linestyle='none', marker='X', color='red', markersize=1, label='Anomaly')
plt.xlabel('Date and Time')
plt.ylabel('Sensor Reading')
plt.title('PS5 Anomalies')
plt.legend(loc='best')
plt.show();

# %%
# Let's plot the outliers from pc1 on top of the sensor_11 and see where they occured in the time series
a = principalDf[principalDf['anomaly_pc1'] == 1] #anomaly
plt.figure(figsize=(18,6))
plt.plot(df['PS6'], color='blue', label='Normal')
plt.plot(df['PS6'], linestyle='none', marker='X', color='red', markersize=1, label='Anomaly')
plt.xlabel('Date and Time')
plt.ylabel('Sensor Reading')
plt.title('PS6 Anomalies')
plt.legend(loc='best')
plt.show();

# %%
# Let's plot the outliers from pc1 on top of the sensor_11 and see where they occured in the time series
a = principalDf[principalDf['anomaly_pc1'] == 1] #anomaly
plt.figure(figsize=(18,6))
plt.plot(df['TS1'], color='blue', label='Normal')
plt.plot(df['TS1'], linestyle='none', marker='X', color='red', markersize=1, label='Anomaly')
plt.xlabel('Date and Time')
plt.ylabel('Sensor Reading')
plt.title('TS1 Anomalies')
plt.legend(loc='best')
plt.show();

# %%
# Let's plot the outliers from pc1 on top of the sensor_11 and see where they occured in the time series
a = principalDf[principalDf['anomaly_pc1'] == 1] #anomaly
plt.figure(figsize=(18,6))
plt.plot(df['TS2'], color='blue', label='Normal')
plt.plot(df['TS2'], linestyle='none', marker='X', color='red', markersize=1, label='Anomaly')
plt.xlabel('Date and Time')
plt.ylabel('Sensor Reading')
plt.title('TS2 Anomalies')
plt.legend(loc='best')
plt.show();

# %%
# Let's plot the outliers from pc1 on top of the sensor_11 and see where they occured in the time series
a = principalDf[principalDf['anomaly_pc1'] == 1] #anomaly
plt.figure(figsize=(18,6))
plt.plot(df['TS3'], color='blue', label='Normal')
plt.plot(df['TS3'], linestyle='none', marker='X', color='red', markersize=1, label='Anomaly')
plt.xlabel('Date and Time')
plt.ylabel('Sensor Reading')
plt.title('TS3 Anomalies')
plt.legend(loc='best')
plt.show();

# %%
# Let's plot the outliers from pc1 on top of the sensor_11 and see where they occured in the time series
a = principalDf[principalDf['anomaly_pc1'] == 1] #anomaly
plt.figure(figsize=(18,6))
plt.plot(df['TS4'], color='blue', label='Normal')
plt.plot(df['TS4'], linestyle='none', marker='X', color='red', markersize=1, label='Anomaly')
plt.xlabel('Date and Time')
plt.ylabel('Sensor Reading')
plt.title('TS3 Anomalies')
plt.legend(loc='best')
plt.show();

# %%
# Let's plot the outliers from pc1 on top of the sensor_11 and see where they occured in the time series
a = principalDf[principalDf['anomaly_pc1'] == 1] #anomaly
plt.figure(figsize=(18,6))
plt.plot(df['FS2'], color='blue', label='Normal')
plt.plot(df['FS2'], linestyle='none', marker='X', color='red', markersize=1, label='Anomaly')
plt.xlabel('Date and Time')
plt.ylabel('Sensor Reading')
plt.title('FS2 Anomalies')
plt.legend(loc='best')
plt.show();

# %%
# Let's plot the outliers from pc1 on top of the sensor_11 and see where they occured in the time series
a = principalDf[principalDf['anomaly_pc1'] == 1] #anomaly
plt.figure(figsize=(18,6))
plt.plot(df['CE1'], color='blue', label='Normal')
plt.plot(df['CE1'], linestyle='none', marker='X', color='red', markersize=1, label='Anomaly')
plt.xlabel('Date and Time')
plt.ylabel('Sensor Reading')
plt.title('CE1 Anomalies')
plt.legend(loc='best')
plt.show();

# %% [markdown]
# Source : https://towardsdatascience.com/anomaly-detection-in-time-series-sensor-data-86fd52e62538
